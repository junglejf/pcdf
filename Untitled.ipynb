# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import diferencas_finitas
# Out:
# Quantos passos você quer dar entre os pontos 0 e 1?3
# passos:
# [0.0, 0.25, 0.5, 0.75, 1.0]
# Quantos valores diferentes assume o k nesse problema? 2
# O primeiro intervalo de k é de 0 até ? 0.5
# E quanto vale k de 0 a 0.5? 0.5
# O segundo intervalo de k é de 0.5 até ? 1
# E quanto vale k de 0.5 a 1.0? 1
#
#
# Valores de k para cada x listado abaixo:
# [0.5, 0.5, 0.5, 1.0, 1.0]
# [0.0, 0.25, 0.5, 0.75, 1.0]

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import diferencas_finitas

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,10)
line, = plt.plot(x,np.sin(x), '--',linewidth=2)

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import diferencas_finitas
